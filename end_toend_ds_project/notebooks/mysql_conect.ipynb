# %%
import sys
sys.path.append("../scripts/")
from absenteeism_module import *
# load the model and scaler
model = absenteeism_model('model', 'scaler')
# preprocess the new dataset
model.load_and_clean_data('Absenteeism_new_data.csv')
# prediction output
model.predicted_outputs()

# %%
df= pd.read_csv('../data/Absenteeism_new_data.csv')
df.columns
# Out:
# Index(['ID', 'Reason for Absence', 'Date', 'Transportation Expense',
#        'Distance to Work', 'Age', 'Daily Work Load Average', 'Body Mass Index',
#        'Education', 'Children', 'Pets'],
#       dtype='object')

# %%
import pymysql
import pandas as pd
from utils import var

# %%
conn = pymysql.connect(database = var['database'],
                        user = var['user'], password = var['password'])

# %%
cursor = conn.cursor()

# %%
qerry ="select * from  predicted_outputs;"
cursor.execute(qerry)
# Out:
# 40

# %%
# after loading the data into the database
data=pd.read_sql("select * from  predicted_outputs;",con=conn)
data.head()
# Out:
# /var/folders/pr/k1cjyyh56sv6wyyxm023snx00000gn/T/ipykernel_86395/1150059437.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   data=pd.read_sql("select * from  predicted_outputs;",con=conn)
#    reason_1  reason_2  reason_3  reason_4  month_value  \
# 0         0         0         0         1            6
# 1         1         0         0         0            6
# 2         0         0         0         1            6
# 3         0         0         0         1            6
# 4         1         0         0         0            6
#
#    transportation_expense  age  body_mass_index  education  children  pet  \
# 0                     179   30               19          1         0    0
# 1                     361   28               27          0         1    4
# ...

# %% [markdown]
# # # Checkpoint 'df_new_obs'

# %%
df_new_obs = model.predicted_outputs()
df_new_obs
# Out:
#     Reason_1  Reason_2  Reason_3  Reason_4  Month Value  \
# 0          0       0.0         0         1            6
# 1          1       0.0         0         0            6
# 2          0       0.0         0         1            6
# 3          0       0.0         0         1            6
# 4          1       0.0         0         0            6
# 5          1       0.0         0         0            6
# 6          1       0.0         0         0            6
# 7          0       0.0         0         1            6
# 8          0       0.0         0         1            6
# 9          1       0.0         0         0            6
# 10         0       0.0         0         1            6
# 11         0       0.0         1         0            6
# 12         0       0.0         1         0            6
# 13         0       0.0         0         1            6
# 14         0       0.0         0         0            6
# 15         0       0.0         0         0            6
# ...

# %%
df_new_obs.to_csv("db_handler/df_new_obs.csv",index=False)

# %% [markdown]
# ## .execute()

# %%
cursor.execute('SELECT * FROM predicted_outputs;')
# Out:
# 0

# %% [markdown]
# ## Creating the INSERT Statement

# %%
insert_query = 'INSERT INTO predicted_outputs VALUES '

# %%
insert_query
# Out:
# 'INSERT INTO predicted_outputs VALUES '

# %%
df_new_obs.shape
# Out:
# (40, 13)

# %%
df_new_obs['Age']
# Out:
# 0     30
# 1     28
# 2     34
# 3     40
# 4     34
# 5     28
# 6     46
# 7     30
# 8     37
# 9     37
# 10    36
# 11    50
# 12    31
# 13    30
# 14    48
# 15    33
# 16    50
# 17    30
# 18    40
# 19    30
# 20    37
# 21    31
# 22    37
# 23    37
# 24    31
# 25    43
# 26    31
# 27    58
# 28    37
# 29    58
# 30    33
# 31    37
# 32    28
# 33    28
# 34    31
# 35    33
# 36    37
# 37    40
# 38    39
# 39    53
# Name: Age, dtype: int64

# %%
df_new_obs[df_new_obs.columns.values[6]][0]
# Out:
# 30

# %%
for i in range(df_new_obs.shape[0]):
    insert_query += '(' 
    
    for j in range(df_new_obs.shape[1]):
        insert_query += str(df_new_obs[df_new_obs.columns.values[j]][i]) + ', '
    
    insert_query = insert_query[:-2] + '), '

# %%
insert_query
# Out:
# 'INSERT INTO predicted_outputs VALUES (0, 0.0, 0, 1, 6, 179, 30, 19, 1, 0, 0, 0.12279926243494323, 0), (1, 0.0, 0, 0, 6, 361, 28, 27, 0, 1, 4, 0.8733923470447209, 1), (0, 0.0, 0, 1, 6, 155, 34, 25, 0, 2, 0, 0.26830495460343223, 0), (0, 0.0, 0, 1, 6, 179, 40, 22, 1, 2, 0, 0.1963853143922252, 0), (1, 0.0, 0, 0, 6, 155, 34, 25, 0, 2, 0, 0.7235017225544896, 1), (1, 0.0, 0, 0, 6, 225, 28, 24, 0, 1, 2, 0.7168905020985188, 1), (1, 0.0, 0, 0, 6, 118, 46, 25, 0, 2, 0, 0.5705238370679658, 1), (0, 0.0, 0, 1, 6, 179, 30, 19, 1, 0, 0, 0.12279926243494323, 0), (0, 0.0, 0, 1, 6, 118, 37, 28, 0, 0, 0, 0.1341180540896835, 0), (1, 0.0, 0, 0, 6, 118, 37, 28, 0, 0, 0, 0.5250065611752316, 1), (0, 0.0, 0, 1, 6, 378, 36, 21, 0, 2, 4, 0.4549980207286245, 0), (0, 0.0, 1, 0, 6, 118, 50, 31, 0, 1, 0, 0.6447416367376194, 1), (0, 0.0, 1, 0, 6, 233, 31, 21, 1, 1, 8, 0.3511076612078474, 0), (0, 0.0, 0, 1, 6, 179, 30, 19, 1, 0, 0, 0.12279926243494323, 0), (0, 0.0, 0, 0, 6, 235, 48, 33, 0, 1, 5, 0.09653346354354148,
# ...

# %%
insert_query = insert_query[:-2] + ';'

# %%
insert_query
# Out:
# 'INSERT INTO predicted_outputs VALUES (0, 0.0, 0, 1, 6, 179, 30, 19, 1, 0, 0, 0.12279926243494323, 0), (1, 0.0, 0, 0, 6, 361, 28, 27, 0, 1, 4, 0.8733923470447209, 1), (0, 0.0, 0, 1, 6, 155, 34, 25, 0, 2, 0, 0.26830495460343223, 0), (0, 0.0, 0, 1, 6, 179, 40, 22, 1, 2, 0, 0.1963853143922252, 0), (1, 0.0, 0, 0, 6, 155, 34, 25, 0, 2, 0, 0.7235017225544896, 1), (1, 0.0, 0, 0, 6, 225, 28, 24, 0, 1, 2, 0.7168905020985188, 1), (1, 0.0, 0, 0, 6, 118, 46, 25, 0, 2, 0, 0.5705238370679658, 1), (0, 0.0, 0, 1, 6, 179, 30, 19, 1, 0, 0, 0.12279926243494323, 0), (0, 0.0, 0, 1, 6, 118, 37, 28, 0, 0, 0, 0.1341180540896835, 0), (1, 0.0, 0, 0, 6, 118, 37, 28, 0, 0, 0, 0.5250065611752316, 1), (0, 0.0, 0, 1, 6, 378, 36, 21, 0, 2, 4, 0.4549980207286245, 0), (0, 0.0, 1, 0, 6, 118, 50, 31, 0, 1, 0, 0.6447416367376194, 1), (0, 0.0, 1, 0, 6, 233, 31, 21, 1, 1, 8, 0.3511076612078474, 0), (0, 0.0, 0, 1, 6, 179, 30, 19, 1, 0, 0, 0.12279926243494323, 0), (0, 0.0, 0, 0, 6, 235, 48, 33, 0, 1, 5, 0.09653346354354148,
# ...

# %%
cursor.execute(insert_query)
# Out:
# 40

# %%
conn.commit()

# %%
conn.close()
